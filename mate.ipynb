# %%
# !wget https://database.lichess.org/lichess_db_puzzle.csv.zst

# %%
import pandas

# %%
df = pandas.read_csv('lichess_db_puzzle.csv.zst')

# %%
df
# Out:
#         PuzzleId                                                FEN  \
# 0          00008  r6k/pp2r2p/4Rp1Q/3p4/8/1N1P2R1/PqP2bPP/7K b - ...
# 1          0000D  5rk1/1p3ppp/pq3b2/8/8/1P1Q1N2/P4PPP/3R2K1 w - ...
# 2          0009B  r2qr1k1/b1p2ppp/pp4n1/P1P1p3/4P1n1/B2P2Pb/3NBP...
# 3          000Vc             8/8/4k1p1/2KpP2p/5PP1/8/8/8 w - - 0 53
# 4          000Zo  4r3/1k6/pp3r2/1b2P2p/3R1p2/P1R2P2/1P4PP/6K1 w ...
# ...          ...                                                ...
# 3366494    zzzYp  3r1rk1/3pN1pp/nq3pn1/1pp1p1QN/4P3/5P2/2P3PP/3R...
# 3366495    zzzc4   3r3k/p5pp/8/5R2/1BQ1p3/P3q3/Bb4PP/6K1 w - - 0 28
# 3366496    zzzco  5Q2/pp3R1P/1kpp4/4p3/2P1P3/3PP2P/Pr2q3/2K5 w -...
# 3366497    zzzhI  r3kb1r/ppp2ppp/2n5/3q3b/3P1B2/5N1P/PPP3P1/RN1Q...
# 3366498    zzzhg  r2q1rk1/4bppp/p1n1pn2/1p1pN3/2pP2b1/1PP1P3/PBQ...
#
#                                  Moves  Rating  RatingDeviation  Popularity  \
# ...

# %%
df[~df['Themes'].str.contains("mate")].sort_values('Rating', ascending=False)
# Out:
#         PuzzleId                                                FEN  \
# 2969192    sgHm8  r2qr1k1/bppn2p1/4b1Q1/PP1p4/3P1R2/B1NpP3/6PP/5...
# 3350489    zhl5i  7k/4QP2/2p2n2/p3P3/P1pP4/1pP2K2/1q3P2/8 b - - ...
# 596862     AzRSf  r3r1k1/1b2b1pN/pq2pp2/7Q/1p1p1B1P/6P1/PPB2P2/4...
# 14848      0H41G  6k1/b3q1p1/p1p2rpp/3Pp3/B7/2P3NP/Pr3PP1/R2QR1K...
# 1028260    Ivt5K  8/p2k3p/1p3p2/2p3p1/2P1P1K1/5P1P/P5P1/8 w - - ...
# ...          ...                                                ...
# 2389664    i14Iu   k7/4b3/pr3p1p/5P2/1Pp2P2/2K3P1/7P/1R6 b - - 1 41
# 2757507    omstz  r2r2k1/5pp1/1p2p2p/p3P3/3R4/2P4P/PP4P1/3R2K1 b...
# 229620     4E5Z8  5r2/5pp1/3p4/1k5p/1P6/2nN3P/5PP1/4R1K1 w - - 3 30
# 3316823    z5MH0  1k1r4/pp3ppp/2b1p3/2p3q1/P1B5/1P3P2/3r2PP/2RR1...
# 1701715    VLzAu  3r1rk1/1p3p2/1ppp2p1/2n5/5PpP/P3R1P1/1PP3B1/4R...
#
#                                                      Moves  Rating  \
# 2969192                      c7c5 b5c6 b7c6 f1f3 a7d4 e3d4    3153
# ...

# %%
compression_opts = dict(method='zip', archive_name='not-mate.csv')  
df[:int(1e6)].to_csv('not-mate-1m.zip', index=False, compression=compression_opts)

# %%
compression_opts = dict(method='zip', archive_name='not-mate.csv')  
df[int(1e6):2*int(1e6)].to_csv('not-mate-2m.zip', index=False, compression=compression_opts)

# %%
compression_opts = dict(method='zip', archive_name='not-mate.csv')  
df[2*int(1e6):].to_csv('not-mate-3m.zip', index=False, compression=compression_opts)
